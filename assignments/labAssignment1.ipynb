# %% [markdown]
# <a href="https://colab.research.google.com/github/SAIGHHLS/musicComputing2025/blob/main/assignments/labAssignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1) Start by importing the necessary libraries in the first cell of the notebook
# numpy
import numpy as np

# matplotlib

import matplotlib.pyplot as plt

# librosa

import librosa
import librosa.display

#import audio files

plotAudio= "/content/musicComputing2025/audioFiles/avm2.wav"

# %%
# 2) Create a function that inputs the name of an audio file and a sampling rate
# print string

import numpy as np
import matplotlib.pyplot as plt
import librosa
import librosa.display

def plotAudio(file,samplingRate):
  print(file,samplingRate)

  # In the function you should use librosa.load() to open the specified filename
  # with the specified sampling rate

  signal, sr = librosa.load(file, sr=samplingRate)

  # Use variables for the x- and y-labels

  time = np.arange(0, len(signal)) / sr

  # The function should plot the time-domain (waveform) representation of the
  # audio signal with time in seconds on the x-axis and amplitude on the y-axis

  plt.figure(figsize=(10, 4))
  plt.plot(time, signal, label="Waveform")
  plt.xlabel("Time (seconds)")
  plt.ylabel("Amplitude")
  plt.title(f"Waveform of {file} at {samplingRate} Hz")
  plt.legend()
  plt.show()

  # Plot the signal

  time = np.arange(0,signal.shape[0])/sr
  plt.plot(time,signal)
  plt.xlabel('Time (seconds)')
  plt.ylabel('Amplitude')
  plt.show()

# %%
# 3) Run the function twice (in different cells)
# First use ‘avm.wav’ as the filename with a sampling rate of 44100

import matplotlib.pyplot as plt
import numpy as np
file = "/content/musicComputing2025/audioFiles/avm.wav"
samplingRate=44100

plotAudio(file,samplingRate)
# Out:
# /content/musicComputing2025/audioFiles/avm.wav 44100

# %%
# Second use ‘avm.wav’ as the filename with a sampling rate of 441

import matplotlib.pyplot as plt
import numpy as np
file2 = "/content/musicComputing2025/audioFiles/avm2.wav"
samplingRate=441

plotAudio(file2,samplingRate)
# Out:
# /content/musicComputing2025/audioFiles/avm2.wav 441
